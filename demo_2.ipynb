# %%
import numpy as np
import pandas as pd

# %%
# tao series 
ser_diem = pd.Series([7.8, 6.7, 9.2])
isum=ser_diem.sum()
iaverage=ser_diem.mean()
imedian=ser_diem.median()
ser_diem[2]
imedian
# Out:
# 7.8

# %%
type(ser_diem)
# Out:
# pandas.core.series.Series

# %%
ser_diem
# Out:
# 0    7.8
# 1    6.7
# 2    9.2
# 3    8.3
# 4    5.4
# dtype: float64

# %%
# index : number va label

# %%
ser_diem = pd.Series([7.8, 6.7, 9.2, 8.3, 5.4], index=['A01', 'A02', 'B03', 'B04', 'C05'])
ser_diem['A05']=10

ser_diem
# Out:
# A01     7.8
# A02     6.7
# B03     9.2
# B04     8.3
# C05     5.4
# A05    10.0
# dtype: float64

# %%
ser_diem
# Out:
# A01    7.8
# A02    6.7
# B03    9.2
# B04    8.3
# C05    5.4
# dtype: float64

# %%
ser_diem['B03']
# Out:
# 9.2

# %%
ser_diem[0]
# Out:
# 7.8

# %%
ser_diem.head(3)
# Out:
# A01    7.8
# A02    6.7
# B03    9.2
# dtype: float64

# %%
ser_diem.tail(3)
# Out:
# B04     8.3
# C05     5.4
# A05    10.0
# dtype: float64

# %%
ser_diem.shape
# Out:
# (6,)

# %%
ser_diem.size
# Out:
# 6

# %%
dict_1={'a':"amy",'b':100,'c':1000}
sd1=pd.Series(dict_1)
sd1
# Out:
# a     amy
# b     100
# c    1000
# dtype: object

# %%
ser_diem.tolist()  # method
# Out:
# [7.8, 6.7, 9.2, 8.3, 5.4]

# %%
ser_diem.values # property
# Out:
# array([7.8, 6.7, 9.2, 8.3, 5.4])

# %%
ser_diem_ = ser_diem.map(lambda x: x+0.5) # bieu thuc lambda

# %%
ser_diem
# Out:
# A01    7.8
# A02    6.7
# B03    9.2
# B04    8.3
# C05    5.4
# dtype: float64

# %%
ser_diem_
# Out:
# A01    8.3
# A02    7.2
# B03    9.7
# B04    8.8
# C05    5.9
# dtype: float64

# %%
def myfunc(x):
    return x*x

# %%
ser_diem.map(myfunc) # map, apply
# Out:
# A01    60.84
# A02    44.89
# B03    84.64
# B04    68.89
# C05    29.16
# dtype: float64

# %%
def myfunc(x):
    if x>=8:
        return x*x
    else:
        return x

# %%
ser_diem.map(myfunc)
# Out:
# A01     7.80
# A02     6.70
# B03    84.64
# B04    68.89
# C05     5.40
# dtype: float64

# %%
ser_diem
# Out:
# A01    7.8
# A02    6.7
# B03    9.2
# B04    8.3
# C05    5.4
# dtype: float64

# %%
ser_note = np.where(ser_diem>=5,"Dat","Rot")

# %%
df = pd.DataFrame({'diem':ser_diem, 'note':ser_note})

# %%
df
# Out:
#      diem note
# A01   7.8  Dat
# A02   6.7  Dat
# B03   9.2  Dat
# B04   8.3  Dat
# C05   5.4  Dat

# %%
ser = pd.Series([1,2,3,2,5,6])
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    2
# 4    5
# 5    6
# dtype: int64

# %%
ser.mode()
# Out:
# 0    2
# dtype: int64

# %%
ser.sum()
# Out:
# 19

# %%
ser.cumsum()
# Out:
# 0     1
# 1     3
# 2     6
# 3     8
# 4    13
# 5    19
# dtype: int64

# %%
ser_diem
# Out:
# A01    7.8
# A02    6.7
# B03    9.2
# B04    8.3
# C05    5.4
# dtype: float64

# %%
ser_diem.describe()
# Out:
# count    5.000000
# mean     7.480000
# std      1.472073
# min      5.400000
# 25%      6.700000
# 50%      7.800000
# 75%      8.300000
# max      9.200000
# dtype: float64

# %%
ser_diem.mean()
# Out:
# 7.4799999999999995

# %%
ser_diem.median()
# Out:
# 7.8

# %%
lst=[1,2,3]
pd1=pd.DataFrame(lst,columns=['So'])
pd1
# Out:
#    So
# 0   1
# 1   2
# 2   3

# %%
lst2=[['Mary',20],['Jony',21],['Tom',22]]
pd2=pd.DataFrame(lst2,columns=['Name','Age'])
pd2
# Out:
#    Name  Age
# 0  Mary   20
# 1  Jony   21
# 2   Tom   22
